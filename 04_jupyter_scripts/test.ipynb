# %%
print('hier')

import math
import matplotlib.pyplot as plt
import numpy as np
import os
from os.path import join
import pandas as pd
import pickle
from pylab import plot, show, savefig, xlim, figure, ylim, legend, boxplot, setp, axes
import shutil
import subprocess
import xarray as xr
import sys


def from_pickle(fn_pickle):
    file = open(fn_pickle, 'rb')
    df = pickle.load(file)
    file.close()      
    return df
# Out:
# hier

# %%
# !git clone https://github.com/vtmvanzelst/BwNCodebook.git
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
cwd = os.getcwd()
print(cwd)

selected_transect = 1

pkl_dir = '../01_transects' +  '/transect_' + str(selected_transect) + '.pkl'
print(pkl_dir)

df_transect = from_pickle(pkl_dir)
print(df_transect)
# Out:
# C:\Users\zelst\OneDrive - Stichting Deltares\Documents\GitHub\BwNCodebook\04_jupyter_scripts
# ../01_transects/transect_1.pkl
#      dist_total  elevation  vegetation
# 0           0.0    -0.9675          -1
# 1          10.0    -0.9675          -1
# 2          20.0    -0.9675          -1
# 3          30.0    -1.0575          -1
# 4          40.0    -1.0700          -1
# ..          ...        ...         ...
# 625      6250.0     1.1900          -1
# 626      6260.0     1.2100          -1
# 627      6270.0     1.2100          -1
# 628      6280.0     1.2100          -1
# 629      6290.0     1.2100          -1
#
# [630 rows x 3 columns]

# %%
main_dir          = 
selected_transect = 1

df_transect = from_pickle(join(main_dir, '01_transects' + '/transect_' + str(selected_transect)) + '.pkl')
